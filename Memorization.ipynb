# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathambiradr12345/Deep-Learning/blob/main/Memorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
def fib(n):
  if n==1 or n==0:
    return 1
  else:
    return fib(n-1) + fib(n-2)

# %%
start=time.time()
fib(8)
print(time.time()-start)
# Out:
# 9.894371032714844e-05
